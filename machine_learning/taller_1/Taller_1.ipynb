# %% [markdown]
# # Hola Profe
#
# Taller 1 - Aprendizaje automático - Ronald Gutierrez - Cristian Árevalo - Karolina Ladino

# %%
#Revisando la versión de lo que vamos a usar

# Python version
import sys
print('Python: {}'.format(sys.version))

import sklearn
print('sklearn: {}'.format(sklearn.__version__))

# Scipy
import scipy
print('scipy: {}'.format(scipy.__version__))

# Numpy
import numpy
print('numpy: {}'.format(numpy.__version__))

# Matplotlib
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))

# Pandas
import pandas
print('pandas: {}'.format(pandas.__version__))

# Scikit-learn
import sklearn
print('sklearn: {}'.format(sklearn.__version__))
# Out:
# Python: 3.6.5 |Anaconda, Inc.| (default, Mar 29 2018, 13:32:41) [MSC v.1900 64 bit (AMD64)]
# sklearn: 0.19.1
# scipy: 1.1.0
# numpy: 1.14.3
# matplotlib: 2.2.2
# pandas: 0.23.0
# sklearn: 0.19.1

# %% [markdown]
# ### Ejercicio IRIS
# Usamos [Rebasedata](https://www.rebasedata.com) para convertir el dataset de CVS a SQLite
# Lo cargaremos y probaremos un querie:

# %%
import sqlite3

# Create a SQL connection to our SQLite database
con = sqlite3.connect("iris.sqlite")

cur = con.cursor()

# The result of a "cursor.execute" can be iterated over by row

# For row in cur.execute('SELECT * FROM sqlite_master WHERE type = "table";'):
# Print(row)
    

# Queries from database
# for row in cur.execute('SELECT Codigo, Peso FROM carros WHERE Clase = "CAMPERO" AND Referencia1="WRANGLER";')
# for row in cur.execute('SELECT * FROM sqlite_master WHERE type = "table";'):

#for row in cur.execute('SELECT sepal_length FROM iris WHERE species = "versicolor";'):
    #print(row)

#Be sure to close the connection.
con.close()

# %% [markdown]
# ### Iniciando con Pandas

# %%
# %matplotlib inline
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("iris.sqlite")
df = pd.read_sql_query("SELECT * from iris", con)

#Dar el número de columnas y filas que tienen el DataFrame
print("(Filas, Columnas) del dataframe: ")
print(df.shape)

#En caso de tener una tabla con muchos datos, da un resumen estadístico de la información 
print("Estadística de los datos: ")
display(HTML(df.describe().to_html()))

#Be sure to close the connection.
con.close()
# Out:
# (Filas, Columnas) del dataframe:
# (150, 5)
# Estadística de los datos:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>150.000000</td>
#       <td>150.000000</td>
#       <td>150.000000</td>
#       <td>150.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>5.843333</td>
#       <td>3.054000</td>
#       <td>3.758667</td>
#       <td>1.198667</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.828066</td>
#       <td>0.433594</td>
#       <td>1.764420</td>
#       <td>0.763161</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>4.300000</td>
#       <td>2.000000</td>
#       <td>1.000000</td>
#       <td>0.100000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>5.100000</td>
# ...

# %% [markdown]
# ### Filtrado y gráfica de la especie 'Setosa'
# Filtrar cada uno de las primeras 4 columnas (sepal_length sepal_width petal_length petal_width) por el tipo de especie (tipos=['setosa','versicolor','virginica']) y realizar una grafica por cada columna con un histograma(ejemplo con panda dataframe.plot.hist o a traves de matplotlib.pyplot.hist) para cada especie

# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as pls

# Create a SQL connection to our SQLite database
con = sqlite3.connect("iris.sqlite")

cur = con.cursor()

for sepal in cur.execute('SELECT sepal_length FROM iris WHERE species = "setosa";'):
    print(sepal)
for species in cur.execute('SELECT species FROM iris WHERE species = "setosa";'):
    print(species)
    
df.plot(x='species', y='sepal_length', kind='bar') 
plt.show()
    
con.close()
# Out:
# (5.1,)
# (4.9,)
# (4.7,)
# (4.6,)
# (5.0,)
# (5.4,)
# (4.6,)
# (5.0,)
# (4.4,)
# (4.9,)
# (5.4,)
# (4.8,)
# (4.8,)
# (4.3,)
# (5.8,)
# (5.7,)
# (5.4,)
# (5.1,)
# (5.7,)
# (5.1,)
# (5.4,)
# (5.1,)
# (4.6,)
# (5.1,)
# (4.8,)
# (5.0,)
# (5.0,)
# (5.2,)
# (5.2,)
# (4.7,)
# (4.8,)
# (5.4,)
# (5.2,)
# (5.5,)
# (4.9,)
# (5.0,)
# (5.5,)
# (4.9,)
# (4.4,)
# (5.1,)
# (5.0,)
# (4.5,)
# (4.4,)
# (5.0,)
# (5.1,)
# (4.8,)
# (5.1,)
# (4.6,)
# (5.3,)
# (5.0,)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ('setosa',)
# ...
